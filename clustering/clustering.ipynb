# %%
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs

X, y = make_blobs([...]) # make the blobs: y contains the cluster IDs, but we
 # will not use them; that's what we want to predict
k = 5
kmeans = KMeans(n_clusters=k, random_state=42)
y_pred = kmeans.fit_predict(X)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 from sklearn.cluster import KMeans
#       2 from sklearn.datasets import make_blobs
# ----> 4 X, y = make_blobs([...]) # make the blobs: y contains the cluster IDs, but we
#       5  # will not use them; that's what we want to predict
#       6 k = 5
#
# File c:\Users\PP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File c:\Users\PP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\datasets\_samples_generator.py:1143, in make_blobs(n_samples, n_features, centers, cluster_std, center_box, shuffle, random_state, return_centers)
#    1140         n_samples_per_center[i] += 1
#    1142 cum_sum_n_samples = np.cumsum(n_samples_per_center)
# -> 1143 X = np.empty(shape=(sum(n_samples_per_center), n_features), dtype=np.float64)
#    1144 y = np.empty(shape=(sum(n_samples_per_center),), dtype=int)
#    1146 for i, (n, std) in enumerate(zip(n_samples_per_center, cluster_std)):
#
# TypeError: unsupported operand type(s) for +: 'int' and 'ellipsis'

# %%
y_pred
y_pred is kmeans.labels_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 y_pred
#       2 y_pred is kmeans.labels_
#
# NameError: name 'y_pred' is not defined

# %%
kmeans.cluster_centers_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 kmeans.cluster_centers_
#
# NameError: name 'kmeans' is not defined

# %%
import numpy as np
X_new = np.array([[0, 2], [3, 2], [-3, 3], [-3, 2.5]])
kmeans.predict(X_new)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 import numpy as np
#       2 X_new = np.array([[0, 2], [3, 2], [-3, 3], [-3, 2.5]])
# ----> 3 means.predict(X_new)
#
# NameError: name 'means' is not defined

# %%
kmeans.transform(X_new).round(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 kmeans.transform(X_new).round(2)
#
# NameError: name 'kmeans' is not defined

# %%
good_init = np.array([[-3, 3], [-3, 2], [-3, 1], [-1, 2], [0, 2]])
kmeans = KMeans(n_clusters=5, init=good_init, n_init=1, random_state=42)
kmeans.fit(X)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 good_init = np.array([[-3, 3], [-3, 2], [-3, 1], [-1, 2], [0, 2]])
#       2 kmeans = KMeans(n_clusters=5, init=good_init, n_init=1, random_state=42)
# ----> 3 kmeans.fit(X)
#
# NameError: name 'X' is not defined

# %%
kmeans.inertia_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 kmeans.inertia_
#
# AttributeError: 'KMeans' object has no attribute 'inertia_'

# %%
kmeans.score(X)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 kmeans.score(X)
#
# NameError: name 'X' is not defined

# %%
from sklearn.cluster import MiniBatchKMeans
minibatch_kmeans = MiniBatchKMeans(n_clusters=5, random_state=42)
minibatch_kmeans.fit(X)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 3
#       1 from sklearn.cluster import MiniBatchKMeans
#       2 minibatch_kmeans = MiniBatchKMeans(n_clusters=5, random_state=42)
# ----> 3 minibatch_kmeans.fit(X)
#
# NameError: name 'X' is not defined

# %%
from sklearn.metrics import silhouette_score
silhouette_score(X, kmeans.labels_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 from sklearn.metrics import silhouette_score
# ----> 2 silhouette_score(X, kmeans.labels_)
#
# NameError: name 'X' is not defined

# %%
from PIL import Image
import numpy as np

image = np.asarray(Image.open(filepath))
image.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 4
#       1 from PIL import Image
#       2 import numpy as np
# ----> 4 image = np.asarray(Image.open(filepath))
#       5 image.shape
#
# NameError: name 'filepath' is not defined

# %%
X = image.reshape(-1, 3)
kmeans = KMeans(n_clusters=8, random_state=42).fit(X)
segmented_img = kmeans.cluster_centers_[kmeans.labels_]
segmented_img = segmented_img.reshape(image.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 X = image.reshape(-1, 3)
#       2 kmeans = KMeans(n_clusters=8, random_state=42).fit(X)
#       3 segmented_img = kmeans.cluster_centers_[kmeans.labels_]
#
# NameError: name 'image' is not defined

# %%
from sklearn.datasets import load_digits
X_digits, y_digits = load_digits(return_X_y=True)
X_train, y_train = X_digits[:1400], y_digits[:1400]
X_test, y_test = X_digits[1400:], y_digits[1400:]

# %%
from sklearn.linear_model import LogisticRegression
n_labeled = 50
log_reg = LogisticRegression(max_iter=10_000)
log_reg.fit(X_train[:n_labeled], y_train[:n_labeled])
# Out:
# LogisticRegression(max_iter=10000)

# %%
log_reg.score(X_test, y_test)
# Out:
# 0.7581863979848866

# %%
k = 50
kmeans = KMeans(n_clusters=k, random_state=42)
X_digits_dist = kmeans.fit_transform(X_train)
representative_digit_idx = np.argmin(X_digits_dist, axis=0)
X_representative_digits = X_train[representative_digit_idx]

# %%
y_representative_digits = np.array([1, 3, 6, 0, 7, 9, 2, ..., 5, 1, 9, 9, 3, 7])

# %%
log_reg = LogisticRegression(max_iter=10_000)
log_reg.fit(X_representative_digits, y_representative_digits)
log_reg.score(X_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 2
#       1 log_reg = LogisticRegression(max_iter=10_000)
# ----> 2 log_reg.fit(X_representative_digits, y_representative_digits)
#       3 log_reg.score(X_test, y_test)
#
# File c:\Users\PP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\PP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:1247, in LogisticRegression.fit(self, X, y, sample_weight)
#    1244 else:
#    1245     _dtype = [np.float64, np.float32]
# -> 1247 X, y = validate_data(
#    1248     self,
#    1249     X,
#    1250     y,
#    1251     accept_sparse="csr",
#    1252     dtype=_dtype,
#    1253     order="C",
#    1254     accept_large_sparse=solver not in ["liblinear", "sag", "saga"],
#    1255 )
#    1256 check_classification_targets(y)
#    1257 self.classes_ = np.unique(y)
#
# File c:\Users\PP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2971, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2969         y = check_array(y, input_name="y", **check_y_params)
#    2970     else:
# -> 2971         X, y = check_X_y(X, y, **check_params)
#    2972     out = X, y
#    2974 if not no_val_X and check_params.get("ensure_2d", True):
#
# File c:\Users\PP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:1387, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1368 X = check_array(
#    1369     X,
#    1370     accept_sparse=accept_sparse,
#    (...)   1382     input_name="X",
#    1383 )
#    1385 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
# -> 1387 check_consistent_length(X, y)
#    1389 return X, y
#
# File c:\Users\PP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:473, in check_consistent_length(*arrays)
#     471 lengths = [_num_samples(X) for X in arrays if X is not None]
#     472 if len(set(lengths)) > 1:
# --> 473     raise ValueError(
#     474         "Found input variables with inconsistent numbers of samples: %r"
#     475         % [int(l) for l in lengths]
#     476     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [50, 14]

# %%
y_train_propagated = np.empty(len(X_train), dtype=np.int64)
for i in range(k):
    y_train_propagated[kmeans.labels_ == i] = y_representative_digits[i]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 3
#       1 y_train_propagated = np.empty(len(X_train), dtype=np.int64)
#       2 for i in range(k):
# ----> 3     y_train_propagated[kmeans.labels_ == i] = y_representative_digits[i]
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'ellipsis'

# %%
log_reg = LogisticRegression()
log_reg.fit(X_train, y_train_propagated)
log_reg.score(X_test, y_test)
# Out:
# c:\Users\PP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.0

# %%
percentile_closest = 99
X_cluster_dist = X_digits_dist[np.arange(len(X_train)), kmeans.labels_]
for i in range(k):
    in_cluster = (kmeans.labels_ == i)
    cluster_dist = X_cluster_dist[in_cluster]
    cutoff_distance = np.percentile(cluster_dist, percentile_closest)
    above_cutoff = (X_cluster_dist > cutoff_distance)
    X_cluster_dist[in_cluster & above_cutoff] = -1

partially_propagated = (X_cluster_dist != -1)
X_train_partially_propagated = X_train[partially_propagated]
y_train_partially_propagated = y_train_propagated[partially_propagated]

# %%
log_reg = LogisticRegression(max_iter=10_000)
log_reg.fit(X_train_partially_propagated, y_train_partially_propagated)
log_reg.score(X_test, y_test)
# Out:
# c:\Users\PP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 10000 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=10000).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.0025188916876574307

# %%
(y_train_partially_propagated == y_train[partially_propagated]).mean()
# Out:
# 0.0014814814814814814

# %%
from sklearn.cluster import DBSCAN
from sklearn.datasets import make_moons
X, y = make_moons(n_samples=1000, noise=0.05)
dbscan = DBSCAN(eps=0.05, min_samples=5)
dbscan.fit(X)
# Out:
# DBSCAN(eps=0.05)

# %%
dbscan.labels_
# Out:
# array([ 0,  1,  2,  5,  6,  0,  1,  3,  0,  4,  3,  2,  5,  6, 14,  6, 11,
#         1,  3,  7,  4,  3,  0,  6,  6,  8,  3,  6,  4,  0,  2,  5,  9, -1,
#        10, 11,  6, 10,  9, 11, 10,  1, 11,  6,  7,  6, -1,  3, 10,  1, 11,
#         6, 10, 11,  1, -1,  6,  1,  1,  4, -1,  1,  3,  1, 11, 10,  6,  2,
#         4,  5,  6, -1, -1,  3, 10,  1,  6,  1,  1,  5, 14,  1,  6, -1, -1,
#         6, -1,  6,  6,  1,  4,  6,  4,  0,  2,  3,  2,  1,  1,  6,  0, 10,
#         4,  6,  9, 10,  2,  6,  5, 14,  0,  1,  3, 12, 11,  9,  3, -1,  6,
#        10,  0,  6, 10,  7, 12,  2,  2,  9,  1, 10, -1,  6,  6,  6,  6,  3,
#        10, 11, 12,  3,  4, 10, -1, 10,  6,  4,  1,  9,  3,  6,  1,  5,  3,
#         6,  1,  2,  4, 10, -1, 11,  4,  4,  2,  3,  6, -1, -1,  6, 12,  1,
#         4, -1,  1, 11, 11,  2,  2, 10,  6,  3,  0,  6, -1,  5,  7,  6,  4,
#        12,  2,  9,  7,  6,  3,  2,  7,  3,  3,  3,  4, -1, 11, 13,  3,  6,
#         3,  0,  2, -1,  4, 13,  6,  6,  4,  3, 12,  4,  9,  7,  3,  1,  2,
#         9,  8,  3,  7, 13, -1,  1,  6,  1,  5,  6, 10,  1,  1,  5, 12, 10,
#        -1,  4,  3,  6,  5, 11, -1,  3, 10,  6,  0,  3, -1,  3, 12,  2,  7,
#         1,  1,  2,  2,  0,  2, -1, 11,  1,  1,  2, 12,  1,  2,  1,  2, 11,
#         1,  1, -1,  6,  0, 10,  6,  6,  4,  6,  1,  4,  4,  9,  2,  5,  6,
#         0,  0,  1,  5, 12, 10,  6,  1, 12,  3,  1,  1, -1,  5,  6,  6, 10,
#         3,  7,  9,  0,  5,  5,  4,  1,  4,  6,  6,  0,  2,  1, 12, 12,  2,
#         1,  3,  4,  0,  3,  4,  3,  2,  1,  2,  4,  0,  2,  5,  6,  1, 12,
#         1,  1,  5,  3, -1,  6, 10,  4,  5,  3,  5,  0, -1, 11, 10,  2,  6,
#         1, -1,  4,  2, 14,  6,  7,  5,  8,  1,  5,  6,  4,  1,  9,  0,  4,
#         6,  0,  4,  5, 10,  1,  0,  6,  3, 12, 11, -1, 10,  6, -1,  9,  1,
#         2,  5,  7, 11,  1,  4,  4,  3, -1,  5,  3, 10,  3,  4, 11,  7,  6,
#         7,  7,  7,  0, 11, -1, -1, 10,  6, 11, 10, 11,  4,  6, 11,  6,  2,
#         6, -1,  6, -1,  5,  3,  0,  6,  0,  2, -1, 12, 12,  2,  4,  4,  2,
#         6,  6,  0, 10,  3, -1,  4,  6,  5,  2,  1,  3,  1,  0,  5,  3,  3,
#         5,  5,  3, 12,  1, -1,  3,  7,  7, -1,  1,  6, -1,  6,  7,  7,  1,
#        11, 11,  6,  2, 12,  3, 12, 11, 10,  6, -1,  3,  7,  3,  0, -1,  9,
#         5,  6,  6, 10,  6,  6, 10,  2,  9, -1, -1, 11,  0, 11,  6, 11,  7,
#         6,  4,  4,  1,  0,  2,  6,  2,  4,  5,  4,  4, 11,  6,  1, 10, -1,
#         6,  6,  2,  7,  4, 11,  6,  2,  6,  1,  0,  6,  6,  6, 10, 12,  2,
#         1,  1,  3,  4,  2, -1,  2,  3, -1,  9, -1, 12, 10, 12, 12,  2,  1,
#         4,  5,  0, -1,  6,  6, 10,  2,  1,  6, 10,  4, -1, 10, -1, -1,  6,
#         2,  1, -1,  4,  0, 10,  9,  1, -1, 11, 11,  5,  1, 11, 11,  0,  2,
#         6,  2,  0,  3,  2, -1, 10,  9, 12,  2, -1, -1,  3,  5,  4,  2,  1,
#         1,  2,  6,  2, -1,  2,  6,  6,  6, 12,  0,  2, 10,  7, 11,  4, -1,
#         2, 10,  9,  3, 10, 12,  2,  1,  3,  4,  6, 12,  6,  6, 11,  5,  1,
#         4,  1,  7,  1, -1,  4,  4,  6,  2, 13,  6,  2,  4,  9,  6,  2, -1,
#         1,  1,  4,  5,  6, -1,  2,  2,  0, 12,  1,  6,  6,  6,  1, 11,  5,
#         7, 10,  1,  3, -1,  1,  5,  1,  1,  2,  1,  3,  6,  9,  7,  3,  1,
#         6,  0,  2,  1, 10,  3,  4, 11, 12,  4,  4,  1, 12,  2,  4,  6,  1,
#        12,  3,  4,  4,  9,  6,  6,  5,  3,  1,  1, 12, 11,  6,  8,  6, 14,
#         6,  3,  3, -1,  3,  0,  5,  6,  0,  3, 10,  6,  6, 12,  0,  1,  1,
#         2,  7,  4,  5, -1, 11,  6,  6,  4,  0,  7,  6,  0,  6,  6,  4, 11,
#        12,  1,  1,  3,  0,  6,  1,  0,  1, 10,  1, 11,  6,  2,  1,  5,  1,
#         1, 12,  3,  2,  0, 13,  4,  3,  9,  4,  1,  1,  6,  2, 12,  6,  0,
#         9,  6,  5,  2,  7, 10, -1, 12,  8,  3,  6,  6,  1,  4,  1,  4,  1,
#         6,  2, 10, 10,  0,  2, 12,  2, 10,  1,  2,  7,  6,  6, 12,  3,  6,
#         0, 10,  3,  6,  3,  5,  4, 10,  0,  3,  1, 11, 10, -1, -1,  1, 11,
#         2, 10,  1,  3,  6,  0, -1,  6,  1,  3, 12,  7, 11,  0,  1,  9,  3,
#         7,  6,  2,  6,  9,  0,  7,  5,  4,  3, 11,  3, -1,  0, 11, 11,  0,
#         4,  4,  4,  6,  4,  0,  9,  1,  4,  2, 12,  6,  2,  1,  6,  4,  1,
#         5,  3,  0, 10,  4,  0,  1,  4,  2,  6, 11, 12,  1,  2,  9,  1, -1,
#        11,  0,  4,  6,  1, 11,  6,  1, -1, 11, 11,  4,  6,  1,  1,  1, 11,
#        -1,  2,  6,  5,  9,  3, -1, 12,  6,  4, -1,  1, -1, -1, 12, 12, -1,
#         2, 10, 12, -1, 12,  0, -1, 10, 10,  6,  6,  7, 10,  1,  0,  5, 11,
#         7, 10,  1, 11,  3,  2,  4, 11,  2,  3,  4,  3,  8,  2,  7,  6,  1,
#        11,  3,  1,  4,  9,  1,  5,  9,  6,  3,  6,  1,  1,  1],
#       dtype=int64)

# %%
dbscan.core_sample_indices_
# Out:
# array([  0,   1,   2,   5,   6,   7,   8,   9,  10,  11,  12,  13,  15,
#         17,  18,  19,  21,  22,  23,  24,  25,  26,  27,  28,  30,  31,
#         32,  34,  35,  36,  37,  38,  39,  41,  42,  43,  44,  47,  48,
#         49,  50,  51,  52,  53,  54,  56,  57,  58,  62,  63,  64,  65,
#         66,  67,  68,  69,  70,  73,  77,  81,  82,  85,  87,  88,  90,
#         91,  92,  94,  95,  96,  97,  98, 100, 102, 103, 104, 105, 106,
#        107, 108, 110, 111, 113, 114, 115, 116, 118, 119, 120, 121, 122,
#        124, 125, 126, 127, 128, 129, 131, 132, 133, 134, 135, 136, 137,
#        138, 139, 140, 141, 143, 144, 145, 146, 147, 148, 149, 152, 153,
#        154, 156, 159, 160, 162, 163, 164, 167, 168, 169, 170, 172, 173,
#        174, 175, 176, 177, 178, 179, 180, 181, 183, 184, 185, 186, 187,
#        188, 189, 190, 191, 192, 193, 194, 195, 196, 197, 201, 203, 204,
#        205, 206, 208, 210, 212, 213, 214, 215, 216, 218, 219, 220, 221,
#        222, 223, 224, 227, 228, 229, 230, 231, 232, 233, 234, 235, 236,
#        237, 239, 240, 241, 242, 243, 245, 247, 248, 249, 251, 252, 253,
#        254, 255, 256, 257, 258, 259, 260, 262, 263, 264, 265, 266, 267,
#        270, 271, 272, 273, 275, 276, 277, 279, 280, 281, 284, 285, 286,
#        287, 288, 290, 291, 292, 293, 294, 295, 297, 298, 299, 300, 302,
#        303, 304, 305, 306, 307, 308, 309, 310, 311, 312, 313, 314, 315,
#        316, 318, 319, 320, 321, 322, 323, 324, 325, 326, 327, 328, 330,
#        331, 332, 333, 334, 335, 336, 337, 338, 339, 340, 341, 342, 343,
#        345, 346, 347, 348, 350, 351, 353, 354, 355, 356, 357, 360, 362,
#        363, 364, 366, 367, 368, 369, 370, 371, 372, 373, 374, 375, 376,
#        378, 379, 380, 381, 382, 383, 386, 387, 389, 390, 391, 392, 393,
#        395, 396, 397, 398, 400, 403, 404, 405, 407, 408, 409, 410, 412,
#        415, 417, 418, 419, 420, 421, 422, 423, 424, 427, 430, 431, 432,
#        433, 434, 436, 437, 438, 439, 440, 441, 442, 444, 445, 446, 448,
#        450, 451, 452, 453, 454, 455, 456, 457, 458, 459, 461, 462, 463,
#        465, 466, 467, 470, 472, 473, 475, 476, 478, 479, 480, 481, 482,
#        484, 487, 488, 489, 490, 492, 493, 494, 495, 496, 497, 498, 499,
#        501, 505, 506, 507, 508, 509, 510, 511, 515, 516, 517, 518, 519,
#        520, 521, 522, 523, 524, 525, 527, 528, 530, 531, 532, 533, 535,
#        536, 538, 540, 541, 542, 543, 544, 545, 546, 547, 548, 550, 551,
#        553, 555, 556, 557, 558, 559, 561, 562, 563, 565, 566, 567, 568,
#        569, 570, 571, 572, 578, 581, 582, 583, 584, 585, 587, 589, 590,
#        591, 592, 596, 597, 598, 599, 601, 602, 604, 607, 608, 610, 611,
#        612, 613, 614, 615, 618, 619, 620, 621, 622, 623, 624, 625, 626,
#        627, 629, 630, 631, 632, 634, 635, 636, 637, 638, 639, 640, 642,
#        644, 645, 646, 648, 649, 651, 652, 654, 655, 656, 657, 658, 659,
#        660, 661, 663, 664, 665, 666, 667, 669, 671, 672, 673, 675, 676,
#        677, 678, 679, 680, 681, 682, 683, 685, 686, 687, 688, 690, 691,
#        692, 694, 695, 696, 698, 699, 700, 701, 702, 703, 704, 705, 706,
#        707, 708, 709, 710, 712, 713, 714, 715, 716, 717, 718, 719, 720,
#        722, 723, 724, 726, 728, 729, 730, 731, 732, 736, 737, 738, 739,
#        740, 741, 742, 744, 745, 746, 747, 748, 750, 753, 754, 755, 756,
#        757, 758, 759, 760, 761, 762, 764, 766, 768, 770, 771, 773, 774,
#        775, 776, 778, 779, 780, 781, 783, 784, 785, 786, 788, 789, 790,
#        792, 793, 795, 796, 797, 798, 799, 800, 802, 803, 804, 806, 807,
#        810, 811, 812, 813, 814, 815, 816, 817, 818, 819, 820, 822, 823,
#        826, 827, 828, 829, 832, 833, 834, 835, 836, 837, 838, 839, 840,
#        841, 842, 843, 844, 845, 848, 849, 850, 852, 853, 854, 855, 859,
#        860, 861, 862, 863, 864, 866, 867, 868, 869, 871, 872, 873, 874,
#        875, 876, 877, 878, 880, 881, 882, 883, 884, 886, 887, 888, 889,
#        890, 891, 892, 893, 894, 895, 896, 897, 898, 899, 900, 901, 902,
#        903, 904, 905, 906, 907, 908, 909, 910, 911, 913, 914, 915, 916,
#        918, 919, 920, 921, 922, 923, 924, 925, 927, 928, 929, 930, 931,
#        932, 933, 934, 936, 937, 939, 942, 943, 944, 946, 949, 950, 953,
#        956, 957, 959, 960, 961, 963, 964, 965, 966, 967, 968, 970, 972,
#        975, 976, 977, 978, 979, 981, 982, 983, 984, 985, 987, 990, 991,
#        992, 993, 994, 995, 996, 997, 998, 999], dtype=int64)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=50)
knn.fit(dbscan.components_, dbscan.labels_[dbscan.core_sample_indices_])
# Out:
# KNeighborsClassifier(n_neighbors=50)

# %%
X_new = np.array([[-0.5, 0], [0, 0.5], [1, -0.1], [2, 1]])
knn.predict(X_new)
# Out:
# array([ 3, 10,  2,  1], dtype=int64)

# %%
y_dist, y_pred_idx = knn.kneighbors(X_new, n_neighbors=1)
y_pred = dbscan.labels_[dbscan.core_sample_indices_][y_pred_idx]
y_pred[y_dist > 0.2] = -1
y_pred.ravel()
# Out:
# array([-1, 10,  2, -1], dtype=int64)

# %%
from sklearn.mixture import GaussianMixture
gm = GaussianMixture(n_components=3, n_init=10)
gm.fit(X)
# Out:
# GaussianMixture(n_components=3, n_init=10)

# %%
gm.weights_
# Out:
# array([0.20480978, 0.20448945, 0.59070077])

# %%
gm.means_
# Out:
# array([[-0.74084403,  0.56568568],
#        [ 1.74246288, -0.05847579],
#        [ 0.49333559,  0.24775503]])

# %%
gm.covariances_
# Out:
# array([[[ 0.05291913,  0.06118451],
#         [ 0.06118451,  0.08786992]],
#
#        [[ 0.05131935,  0.0602303 ],
#         [ 0.0602303 ,  0.08570513]],
#
#        [[ 0.17030738, -0.10215275],
#         [-0.10215275,  0.28784075]]])
